# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
    
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
    
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.ExcelFile(r'C:\Users\Lenovo\Dropbox\My PC (DESKTOP-A092I20)\Desktop\File per machine learning\Data Science e Cooperazione\Intentions1.xlsx')
print(df)

# %%
mydata=pd.read_excel(r'C:\Users\Lenovo\Dropbox\My PC (DESKTOP-A092I20)\Desktop\File per machine learning\Data Science e Cooperazione\Intentions1.xlsx')
mydata.head()
# Out:
#    interview_mode  camp_name  hhh  age_respondent  gender_respondent  \
# 0               0          7    0              33                  1
# 1               0          7    1              31                  0
# 2               0          7    1              40                  1
# 3               0          7    1              40                  0
# 4               0          7    1              21                  0
#
#    n of months displaced  idp_displacement_numbers  district_origin  \
# 0                     56                         1               12
# 1                     53                         1               12
# 2                     54                         2               12
# 3                     54                         2                5
# 4                     56                         1               12
#
#    num_hh_member  num_family_member  ...  why_not_return.lack_healthcare  \
# ...

# %%
correlated_features = set()

# %%
correlation_matrix = mydata.drop('wish_to_return', axis=1).corr()
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i,j])>0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)

# %%
correlated_features
# Out:
# {'electricity_available', 'num_family_member', 'tot_female'}

# %%
X= mydata.drop('wish_to_return', axis=1)
target = mydata['wish_to_return']

# %%
rfc = RandomForestClassifier(random_state=101)
rfecv = RFECV(estimator = rfc, step=1, cv=StratifiedKFold(10), scoring='accuracy')
rfecv.fit(X,target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-7b689c51035d> in <module>
#       1 rfc = RandomForestClassifier(random_state=101)
#       2 rfecv = RFECV(estimator = rfc, step=1, cv=StratifiedKFold(10), scoring='accuracy')
# ----> 3 rfecv.fit(X,target)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_rfe.py in fit(self, X, y, groups)
#     506         """
#     507         tags = self._get_tags()
# --> 508         X, y = self._validate_data(
#     509             X, y, accept_sparse="csr", ensure_min_features=2,
#     510             force_all_finite=not tags.get('allow_nan', True),
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# ...
